# %%
import pygame
from pygame.locals import *

pygame.init()
pygame.joystick.init()

joystick_count = pygame.joystick.get_count()

if joystick_count == 0:
    print("No controller attached")
else:
    for i in range (joystick_count):
        joystick = pygame.joystick.Joystick(i)
        print(f"Controller {i}: {joystick.get_name()}")
    print("Select joystick number :")
    
    number = input()
    number = int(number)
    joystick = pygame.joystick.Joystick(number)
    joystick.init()
    print(f"Controller attached: {joystick.get_name()}")
    
axis_count = joystick.get_numaxes()
print(f"Number of axis: {axis_count}")

print("axis number :")
axis_number = input()
axis_number = int(axis_number)

try:
    while True:
        for event in pygame.event.get():
            if event.type == JOYAXISMOTION:
                if event.axis == axis_number:
                    sensitivity = (event.value +1.0) / 2.0 * 255
                    print(f"R2 sensitivity: {int(sensitivity)}")

except KeyboardInterrupt:
    print("Exiting...")
    pygame.quit()
# Out:
# Controller 0: Nintendo Switch Pro Controller
# Controller 1: Nefarius Software Solutions e.U. DS3 Compatible HID Device
# Select joystick number :
#  1
# Controller attached: Nefarius Software Solutions e.U. DS3 Compatible HID Device
# Number of axis: 6
# axis number :
#  5
# R2 sensitivity: 0
# R2 sensitivity: 64
# R2 sensitivity: 245
# R2 sensitivity: 255
# R2 sensitivity: 138
# R2 sensitivity: 33
# R2 sensitivity: 0
# R2 sensitivity: 124
# R2 sensitivity: 255
# R2 sensitivity: 253
# R2 sensitivity: 72
# R2 sensitivity: 0
# R2 sensitivity: 13
# R2 sensitivity: 33
# R2 sensitivity: 44
# R2 sensitivity: 51
# R2 sensitivity: 57
# R2 sensitivity: 65
# R2 sensitivity: 83
# R2 sensitivity: 110
# R2 sensitivity: 138
# R2 sensitivity: 159
# R2 sensitivity: 196
# R2 sensitivity: 221
# R2 sensitivity: 226
# R2 sensitivity: 225
# R2 sensitivity: 219
# R2 sensitivity: 193
# R2 sensitivity: 161
# R2 sensitivity: 140
# R2 sensitivity: 129
# R2 sensitivity: 124
# R2 sensitivity: 130
# R2 sensitivity: 139
# R2 sensitivity: 154
# R2 sensitivity: 165
# R2 sensitivity: 181
# R2 sensitivity: 206
# R2 sensitivity: 217
# R2 sensitivity: 224
# R2 sensitivity: 238
# R2 sensitivity: 255
# R2 sensitivity: 152
# R2 sensitivity: 94
# R2 sensitivity: 44
# R2 sensitivity: 0
# R2 sensitivity: 10
# R2 sensitivity: 38
# R2 sensitivity: 63
# R2 sensitivity: 75
# R2 sensitivity: 87
# R2 sensitivity: 93
# R2 sensitivity: 106
# R2 sensitivity: 131
# R2 sensitivity: 160
# R2 sensitivity: 213
# R2 sensitivity: 222
# R2 sensitivity: 227
# R2 sensitivity: 229
# R2 sensitivity: 228
# R2 sensitivity: 225
# R2 sensitivity: 220
# R2 sensitivity: 219
# R2 sensitivity: 218
# R2 sensitivity: 219
# R2 sensitivity: 222
# R2 sensitivity: 231
# R2 sensitivity: 255
# R2 sensitivity: 160
# R2 sensitivity: 92
# R2 sensitivity: 50
# R2 sensitivity: 0
# R2 sensitivity: 19
# R2 sensitivity: 56
# R2 sensitivity: 92
# R2 sensitivity: 123
# R2 sensitivity: 155
# R2 sensitivity: 188
# R2 sensitivity: 213
# R2 sensitivity: 219
# R2 sensitivity: 222
# R2 sensitivity: 224
# R2 sensitivity: 221
# R2 sensitivity: 219
# R2 sensitivity: 217
# R2 sensitivity: 219
# R2 sensitivity: 222
# R2 sensitivity: 238
# R2 sensitivity: 255
# R2 sensitivity: 211
# R2 sensitivity: 143
# R2 sensitivity: 110
# R2 sensitivity: 93
# R2 sensitivity: 82
# R2 sensitivity: 69
# R2 sensitivity: 48
# R2 sensitivity: 22
# R2 sensitivity: 0
# R2 sensitivity: 5
# R2 sensitivity: 34
# R2 sensitivity: 45
# R2 sensitivity: 53
# R2 sensitivity: 70
# R2 sensitivity: 96
# R2 sensitivity: 120
# R2 sensitivity: 139
# R2 sensitivity: 158
# R2 sensitivity: 174
# R2 sensitivity: 206
# R2 sensitivity: 214
# R2 sensitivity: 219
# R2 sensitivity: 223
# R2 sensitivity: 225
# R2 sensitivity: 226
# R2 sensitivity: 227
# R2 sensitivity: 226
# R2 sensitivity: 225
# R2 sensitivity: 223
# R2 sensitivity: 221
# R2 sensitivity: 220
# R2 sensitivity: 221
# R2 sensitivity: 220
# R2 sensitivity: 223
# R2 sensitivity: 237
# R2 sensitivity: 255
# R2 sensitivity: 183
# R2 sensitivity: 105
# R2 sensitivity: 20
# R2 sensitivity: 0
# Exiting...
